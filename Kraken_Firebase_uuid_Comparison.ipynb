# %% [markdown]
# <a href="https://colab.research.google.com/github/cindyangelira/cindyangelira/blob/main/Kraken_Firebase_uuid_Comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Setup Bigquery

from google.colab import auth
from google.cloud import bigquery
from google.colab import data_table

# %%
# @title Dependencies

import numpy as np
import pandas as pd
import plotly.express as px
from datetime import datetime

# %%
project1 = 'fullstackcustomer' # Project ID inserted based on the query results selected to explore
location1 = 'asia-southeast1' # Location inserted based on the query results selected to explore
client1 = bigquery.Client(project=project1, location=location1)
data_table.enable_dataframe_formatter()
auth.authenticate_user()

# %%
# @title Query Firebase Analytic

sql_query1 = ('''SELECT 
event_date,event_timestamp, user_pseudo_id, 
event_name, (SELECT value.string_value FROM UNNEST(event_params)
WHERE key = "user_uuid") AS uuid
FROM `fullstackcustomer.analytics_212122878.events_*`''')

# %%
# @title Store to Dataframe

firebase_df = client1.query(sql_query1).to_dataframe()
firebase_df.head()
# Out:
#   event_date   event_timestamp                    user_pseudo_id  event_name  \
# 0   20221112  1668217641160000  89c5ad85fc48763ee53af1da4285c497  app_update
# 1   20221112  1668232893803000  9e82eb91dba05df10824141bfb4dd692  app_update
# 2   20221112  1668269022931000  8e66ff7fad01d3f5028de69bc8ea5133  app_update
# 3   20221112  1668222551274000  6766c5b658ec2135766e25c0668a1182  app_update
# 4   20221112  1668261176667000  14210b4ed1d3b3c78dc780a584e8cee9  app_update
#
#    uuid
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None

# %%
firebase_df['event_date'] = pd.to_datetime(firebase_df.event_date)
firebase_df['event_timestamp'] = firebase_df['event_timestamp']/(10**6)
firebase_df['event_timestamp'] = [datetime.fromtimestamp(x) for x in firebase_df['event_timestamp']]
firebase_df.head()
# Out:
#   event_date         event_timestamp                    user_pseudo_id  \
# 0 2022-11-12 2022-11-12 01:47:21.160  89c5ad85fc48763ee53af1da4285c497
# 1 2022-11-12 2022-11-12 06:01:33.803  9e82eb91dba05df10824141bfb4dd692
# 2 2022-11-12 2022-11-12 16:03:42.931  8e66ff7fad01d3f5028de69bc8ea5133
# 3 2022-11-12 2022-11-12 03:09:11.274  6766c5b658ec2135766e25c0668a1182
# 4 2022-11-12 2022-11-12 13:52:56.667  14210b4ed1d3b3c78dc780a584e8cee9
#
#    event_name  uuid
# 0  app_update  None
# 1  app_update  None
# 2  app_update  None
# 3  app_update  None
# 4  app_update  None

# %%
min(firebase_df.event_timestamp), max(firebase_df.event_timestamp)
# Out:
# (Timestamp('2022-09-22 00:00:00.222000'),
#  Timestamp('2022-11-20 23:57:47.407014'))

# %%
# @title Query Kraken Customers Orders

project2 = 'octopus-data-prod-294206'
location2 = 'US'
client2 = bigquery.Client(project = project2, location=location2)

sql_query2 = ('''
WITH users AS(
  SELECT *,
  CASE WHEN premium_id IS NULL THEN 'not premium' ELSE 'premium' END AS premium_status
  FROM `octopus-data-prod-294206.KRAKEN_temp_view.customer_users`
  ),
orders AS(
  SELECT * FROM `octopus-data-prod-294206.KRAKEN_temp_view.customer_orders`
  )
SELECT t1.*, t2.uuid, t2.premium_status
FROM orders t1
LEFT JOIN users t2 ON t1.user_id = t2.user_id
''')

# %%
kraken_order = client2.query(sql_query2).to_dataframe()
kraken_order.head()
# Out:
# Warning: Total number of columns (22) exceeds max_columns (20). Falling back to pandas display.
#                                order_id system                  timestamp  \
# 0  74a2fdf7-6c62-4b2b-8402-bd729feef14b     V2 2021-06-08 04:28:43.991329
# 1  c0a1de17-591e-4d34-ab05-38a4255b23f1     V2 2021-06-14 03:48:58.558019
# 2  95f46fde-9b93-4069-877d-09a185cfdfb9     V2 2021-06-13 03:45:30.140950
# 3  fa60b03a-cfde-4eac-81da-a98aaa0b4f3c     V2 2021-06-27 08:19:03.694438
# 4  3dabbe2f-0241-43b3-a53e-b78bdabe963f     V2 2021-07-22 05:05:18.865012
#
#   total_quantity total_amount   total_weight  user_id  receiver_id  region_id  \
# 0   10.000000000         0E-9  250.000000000    66711         <NA>          8
# 1   12.000000000         0E-9  250.000000000    64836         <NA>          8
# 2   12.000000000         0E-9  250.000000000    64836         <NA>          8
# 3   28.000000000         0E-9  250.000000000    67965         <NA>          8
# 4   11.000000000  6.000000000  313.510000000    67197         <NA>          8
#
#   region_name  ...    country    province     city             district  \
# 0     Bandung  ...  Indonesia  Jawa Barat  Bandung  Kecamatan Cangkuang
# 1     Bandung  ...  Indonesia  Jawa Barat  Bandung             Cileunyi
# 2     Bandung  ...  Indonesia  Jawa Barat  Bandung             Cileunyi
# 3     Bandung  ...  Indonesia  Jawa Barat  Bandung             Cileunyi
# 4     Bandung  ...  Indonesia  Jawa Barat  Bandung             Cileunyi
#
#           village order_status route_id total_distance  \
# 0        Ciluncat    cancelled     <NA>            NaN
# 1         Cinunuk    cancelled     <NA>            NaN
# 2         Cinunuk    cancelled     <NA>            NaN
# 3         Cimekar    cancelled     <NA>            NaN
# 4  Cileunyi Kulon    cancelled     <NA>            NaN
#
#                                    uuid  premium_status
# 0  cb92c691-c767-4ec6-a669-a9def607da8a     not premium
# 1  19074c45-fbae-4597-b65b-8efd15218fb0         premium
# 2  19074c45-fbae-4597-b65b-8efd15218fb0         premium
# 3  a0006b8c-0a33-4ee0-b616-c38282362b6c     not premium
# 4  cc80ca92-be79-476c-8cb1-2c2b8f68c43e     not premium
#
# [5 rows x 22 columns]

# %%
kraken_order.shape
# Out:
# (46043, 22)

# %%
kraken_order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46043 entries, 0 to 46042
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        46043 non-null  object
#  1   system          46043 non-null  object
#  2   timestamp       46043 non-null  datetime64[ns]
#  3   total_quantity  41139 non-null  object
#  4   total_amount    41139 non-null  object
#  5   total_weight    41139 non-null  object
#  6   user_id         46043 non-null  Int64
#  7   receiver_id     31369 non-null  Int64
#  8   region_id       46043 non-null  Int64
#  9   region_name     46043 non-null  object
#  10  latitude        46043 non-null  float64
#  11  longitude       46043 non-null  float64
#  12  country         45856 non-null  object
#  13  province        45830 non-null  object
#  14  city            45830 non-null  object
#  15  district        45758 non-null  object
#  16  village         45804 non-null  object
#  17  order_status    46043 non-null  object
#  18  route_id        27017 non-null  Int64
#  19  total_distance  27017 non-null  float64
#  20  uuid            45999 non-null  object
#  21  premium_status  45999 non-null  object
# dtypes: Int64(4), datetime64[ns](1), float64(3), object(14)
# memory usage: 7.9+ MB

# %%
# @title Filter Kraken Based on Firebase Date

kraken_order_filter = kraken_order[(kraken_order['timestamp'] >= min(firebase_df.event_timestamp)) & (kraken_order['timestamp'] <= max(firebase_df.event_timestamp))]

# %%
kraken_order_filter.head()
# Out:
# Warning: Total number of columns (22) exceeds max_columns (20). Falling back to pandas display.
#                                  order_id system                  timestamp  \
# 73   26425f62-9d32-4ff3-9aee-28c6ba1935bc     V2 2022-11-12 05:08:59.876230
# 97   c185af39-30eb-40ba-993a-5735489318de     V2 2022-10-04 06:36:03.297683
# 101  d06d9816-1226-48e6-bc06-a7a410e1e513     V2 2022-11-14 01:33:50.106634
# 108  a4a447ad-3c55-415e-b81a-d1cf01590bde     V2 2022-11-02 04:43:17.953163
# 110  b6aac303-f0d1-4d06-9a44-8d375ff03f1d     V2 2022-11-19 18:01:55.537190
#
#     total_quantity  total_amount  total_weight  user_id  receiver_id  \
# 73    10.000000000  20.000000000  68.411000000   117146         <NA>
# 97            None          None          None   111879            1
# 101   16.000000000          0E-9   5.000000000   109482         <NA>
# 108   10.000000000  13.000000000  37.271000000    81422         <NA>
# 110   10.000000000  10.000000000  15.151000000   117979         <NA>
#
#      region_id      region_name  ...    country    province  \
# 73           2             Bali  ...  Indonesia        Bali
# 97           3  Other Indonesia  ...  Indonesia  Jawa Barat
# 101          8          Bandung  ...  Indonesia  Jawa Barat
# 108          8          Bandung  ...  Indonesia  Jawa Barat
# 110          2             Bali  ...  Indonesia        Bali
#
#                     city             district            village order_status  \
# 73   Kabupaten Klungkung  Kecamatan Klungkung   Semarapura Kelod    cancelled
# 97            Kota Depok   Kecamatan Sawangan      Sawangan Baru    cancelled
# 101         Kota Bandung        Bandung Kulon  Cigondewah Rahayu    cancelled
# 108    Kabupaten Bandung  Kecamatan Rancaekek          Bojongloa    cancelled
# 110             Denpasar       Denpasar Utara              Ubung    cancelled
#
#     route_id total_distance                                  uuid  \
# 73      <NA>            NaN  f15c301a-7948-4b80-a8e1-50e8b4203241
# 97      <NA>            NaN  61bd4559-b75b-461d-83a9-08476490b981
# 101     <NA>            NaN  1be8a4c5-d4e8-4705-b325-3c25d192d561
# 108     <NA>            NaN  1ed87bf7-dbd9-4a8f-aa90-cc634f5c6c5c
# 110     <NA>            NaN  53991a5d-57ba-4e5f-bcd6-f6001b88cc13
#
#      premium_status
# 73      not premium
# 97      not premium
# 101     not premium
# 108         premium
# 110     not premium
#
# [5 rows x 22 columns]

# %%
min(kraken_order_filter.timestamp), max(kraken_order_filter.timestamp)
# Out:
# (Timestamp('2022-09-22 01:36:18.684898'),
#  Timestamp('2022-11-20 23:04:42.412080'))

# %%
# @title Extract uuid from Kraken and Firebase

uuid_kraken = kraken_order_filter.dropna(subset=['uuid']).uuid.unique()
uuid_firebase = firebase_df.dropna(subset = ['uuid']).uuid.unique()

# %%
len(uuid_kraken), len(uuid_firebase)
# Out:
# (3614, 11975)

# %%
# @title Add New Column *user_in_firebase* on Kraken Customer Orders
# yes if user uuid in Kraken is also captured in firebase, otherwise no

kraken_order_filter['user_in_firebase'] = np.where(kraken_order_filter['uuid'].isin(uuid_firebase), "Yes", "No")
kraken_order_filter.head()
# Out:
# Warning: Total number of columns (23) exceeds max_columns (20). Falling back to pandas display.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                                  order_id system                  timestamp  \
# 73   26425f62-9d32-4ff3-9aee-28c6ba1935bc     V2 2022-11-12 05:08:59.876230
# 97   c185af39-30eb-40ba-993a-5735489318de     V2 2022-10-04 06:36:03.297683
# 101  d06d9816-1226-48e6-bc06-a7a410e1e513     V2 2022-11-14 01:33:50.106634
# 108  a4a447ad-3c55-415e-b81a-d1cf01590bde     V2 2022-11-02 04:43:17.953163
# 110  b6aac303-f0d1-4d06-9a44-8d375ff03f1d     V2 2022-11-19 18:01:55.537190
#
#     total_quantity  total_amount  total_weight  user_id  receiver_id  \
# 73    10.000000000  20.000000000  68.411000000   117146         <NA>
# 97            None          None          None   111879            1
# 101   16.000000000          0E-9   5.000000000   109482         <NA>
# 108   10.000000000  13.000000000  37.271000000    81422         <NA>
# 110   10.000000000  10.000000000  15.151000000   117979         <NA>
#
#      region_id      region_name  ...    province                 city  \
# 73           2             Bali  ...        Bali  Kabupaten Klungkung
# 97           3  Other Indonesia  ...  Jawa Barat           Kota Depok
# 101          8          Bandung  ...  Jawa Barat         Kota Bandung
# 108          8          Bandung  ...  Jawa Barat    Kabupaten Bandung
# 110          2             Bali  ...        Bali             Denpasar
#
#                 district            village order_status route_id  \
# 73   Kecamatan Klungkung   Semarapura Kelod    cancelled     <NA>
# 97    Kecamatan Sawangan      Sawangan Baru    cancelled     <NA>
# 101        Bandung Kulon  Cigondewah Rahayu    cancelled     <NA>
# 108  Kecamatan Rancaekek          Bojongloa    cancelled     <NA>
# 110       Denpasar Utara              Ubung    cancelled     <NA>
#
#     total_distance                                  uuid  premium_status  \
# 73             NaN  f15c301a-7948-4b80-a8e1-50e8b4203241     not premium
# 97             NaN  61bd4559-b75b-461d-83a9-08476490b981     not premium
# 101            NaN  1be8a4c5-d4e8-4705-b325-3c25d192d561     not premium
# 108            NaN  1ed87bf7-dbd9-4a8f-aa90-cc634f5c6c5c         premium
# 110            NaN  53991a5d-57ba-4e5f-bcd6-f6001b88cc13     not premium
#
#      user_in_firebase
# 73                Yes
# 97                 No
# 101               Yes
# 108               Yes
# 110               Yes
#
# [5 rows x 23 columns]

# %%
kraken_order_filter.user_in_firebase.value_counts()
# Out:
# Yes    7631
# No      889
# Name: user_in_firebase, dtype: int64

# %%
# @title Print Kraken Orders Data that *uuid* is not Captured in Firebase

kraken_order_filter[kraken_order_filter['user_in_firebase']=='No'].head()
# Out:
# Warning: Total number of columns (23) exceeds max_columns (20). Falling back to pandas display.
#                                  order_id system                  timestamp  \
# 97   c185af39-30eb-40ba-993a-5735489318de     V2 2022-10-04 06:36:03.297683
# 195  8256d540-dbc9-48bb-8100-184fa3933cc8     V2 2022-10-24 18:56:52.331662
# 209  457de831-b865-4395-8605-e9879b6fe7a4     V2 2022-10-24 02:01:58.630472
# 217  9d14e268-63de-4890-a454-dcd734573379     V2 2022-11-18 05:42:46.741114
# 225  800df737-f5b4-4160-af1b-ca3e8a286396     V2 2022-10-27 15:23:07.827094
#
#     total_quantity      total_amount     total_weight  user_id  receiver_id  \
# 97            None              None             None   111879            1
# 195    2.000000000  190000.000000000  13000.000000000   113677         <NA>
# 209    1.000000000   40000.000000000   3000.000000000   113618         <NA>
# 217    3.000000000     800.000000000   1000.000000000   109059         1706
# 225    5.500000000   16650.000000000   4000.000000000   113068         <NA>
#
#      region_id      region_name  ...                       province  \
# 97           3  Other Indonesia  ...                     Jawa Barat
# 195         13          Jakarta  ...                         Banten
# 209         13          Jakarta  ...                         Banten
# 217         13          Jakarta  ...                     Jawa Barat
# 225         13          Jakarta  ...  Daerah Khusus Ibukota Jakarta
#
#                        city                 district        village  \
# 97               Kota Depok       Kecamatan Sawangan  Sawangan Baru
# 195  Kota Tangerang Selatan       Kecamatan Pamulang     Benda Baru
# 209  Kota Tangerang Selatan  Kecamatan Serpong Utara       Pakualam
# 217             Kota Bekasi             Pondokmelati     Jatimelati
# 225      Kota Jakarta Barat     Kecamatan Cengkareng   Duri Kosambi
#
#     order_status route_id total_distance  \
# 97     cancelled     <NA>            NaN
# 195    cancelled     <NA>            NaN
# 209    cancelled     <NA>            NaN
# 217    cancelled     <NA>            NaN
# 225    cancelled     <NA>            NaN
#
#                                      uuid  premium_status  user_in_firebase
# 97   61bd4559-b75b-461d-83a9-08476490b981     not premium                No
# 195  4e9422dc-646d-4ee9-9116-4a7368a72551     not premium                No
# 209  08bf890d-daa3-44d4-a43b-2f1fe1bbbe3f     not premium                No
# 217  08a84791-be60-4912-b016-2234943ba63a     not premium                No
# 225  0c602f8d-c92a-4309-b160-172c849df939     not premium                No
#
# [5 rows x 23 columns]

# %%
kraken_order_filter[kraken_order_filter['user_in_firebase']=='No'].uuid.nunique()
# Out:
# 620

# %%
# @title Add New Column *user_in_kraken* on Firebase Analytic

# yes if user uuid in Kraken is also captured in firebase, otherwise no

firebase_df['user_in_kraken'] = np.where(firebase_df['uuid'].isin(uuid_kraken), "Yes", "No")
firebase_df.head()
# Out:
# Warning: Total number of columns (23) exceeds max_columns (20). Falling back to pandas display.
#                                  order_id system                  timestamp  \
# 73   26425f62-9d32-4ff3-9aee-28c6ba1935bc     V2 2022-11-12 05:08:59.876230
# 97   c185af39-30eb-40ba-993a-5735489318de     V2 2022-10-04 06:36:03.297683
# 101  d06d9816-1226-48e6-bc06-a7a410e1e513     V2 2022-11-14 01:33:50.106634
# 108  a4a447ad-3c55-415e-b81a-d1cf01590bde     V2 2022-11-02 04:43:17.953163
# 110  b6aac303-f0d1-4d06-9a44-8d375ff03f1d     V2 2022-11-19 18:01:55.537190
#
#     total_quantity  total_amount  total_weight  user_id  receiver_id  \
# 73    10.000000000  20.000000000  68.411000000   117146         <NA>
# 97            None          None          None   111879            1
# 101   16.000000000          0E-9   5.000000000   109482         <NA>
# 108   10.000000000  13.000000000  37.271000000    81422         <NA>
# 110   10.000000000  10.000000000  15.151000000   117979         <NA>
#
#      region_id      region_name  ...    province                 city  \
# 73           2             Bali  ...        Bali  Kabupaten Klungkung
# 97           3  Other Indonesia  ...  Jawa Barat           Kota Depok
# 101          8          Bandung  ...  Jawa Barat         Kota Bandung
# 108          8          Bandung  ...  Jawa Barat    Kabupaten Bandung
# 110          2             Bali  ...        Bali             Denpasar
#
#                 district            village order_status route_id  \
# 73   Kecamatan Klungkung   Semarapura Kelod    cancelled     <NA>
# 97    Kecamatan Sawangan      Sawangan Baru    cancelled     <NA>
# 101        Bandung Kulon  Cigondewah Rahayu    cancelled     <NA>
# 108  Kecamatan Rancaekek          Bojongloa    cancelled     <NA>
# 110       Denpasar Utara              Ubung    cancelled     <NA>
#
#     total_distance                                  uuid  premium_status  \
# 73             NaN  f15c301a-7948-4b80-a8e1-50e8b4203241     not premium
# 97             NaN  61bd4559-b75b-461d-83a9-08476490b981     not premium
# 101            NaN  1be8a4c5-d4e8-4705-b325-3c25d192d561     not premium
# 108            NaN  1ed87bf7-dbd9-4a8f-aa90-cc634f5c6c5c         premium
# 110            NaN  53991a5d-57ba-4e5f-bcd6-f6001b88cc13     not premium
#
#      user_in_firebase
# 73                Yes
# 97                 No
# 101               Yes
# 108               Yes
# 110               Yes
#
# [5 rows x 23 columns]

# %%
firebase_df.iloc[:,-1].value_counts()
# Out:
# No     1031540
# Yes     599882
# Name: user_in_kraken, dtype: int64

# %%
def plot_count(col, labels): #labels only take string
  count_table = pd.DataFrame(col.value_counts())
  fig = px.bar(count_table, x=count_table.iloc[:,0], color = count_table.index, labels= {'x':'Count', 'index':''}, title = 'How many transaction that also captured in '+labels+' ?')
  fig.show()

# %%
# @title Count Transaction in Kraken that Captured in Firebase

plot_count(kraken_order_filter.user_in_firebase, labels = 'Firebase')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="73a97dbb-bf8a-4357-a03b-0d2ccf13c847" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73a97dbb-bf8a-4357-a03b-0d2ccf13c847")) {                    Plotly.newPlot(                        "73a97dbb-bf8a-4357-a03b-0d2ccf13c847",                        [{"alignmentgroup":"True","hovertemplate":"=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Yes","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"h","showlegend":true,"textposition":"auto","x":[7631],"xaxis":"x","y":["Yes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"No","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"h","showlegend":true,"textposition":"auto","x":[889],"xaxis":"x","y":["No"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type" ...

# %%
# @title Count Transaction in Firebase that Captured in Kraken

plot_count(firebase_df.user_in_kraken, labels = 'Kraken')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="92151727-35ed-41a2-984a-ca48ad4c8728" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("92151727-35ed-41a2-984a-ca48ad4c8728")) {                    Plotly.newPlot(                        "92151727-35ed-41a2-984a-ca48ad4c8728",                        [{"alignmentgroup":"True","hovertemplate":"=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"h","showlegend":true,"textposition":"auto","x":[1031540],"xaxis":"x","y":["No"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Yes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"h","showlegend":true,"textposition":"auto","x":[599882],"xaxis":"x","y":["Yes"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""}, ...

# %%
# @title Let's Assume That Our Main Focus is Number of User That Not Captured

kraken_order_filter_user = kraken_order_filter.drop_duplicates(subset = ['uuid'])
firebase_user_df = firebase_df.drop_duplicates(subset = ['uuid'])

# %%
# @title Count *uuid* in Kraken that Captured in Firebase

plot_count(kraken_order_filter_user.user_in_firebase, labels = 'Firebase')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="12d16a29-8ec6-436f-9a47-012de6111f6d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12d16a29-8ec6-436f-9a47-012de6111f6d")) {                    Plotly.newPlot(                        "12d16a29-8ec6-436f-9a47-012de6111f6d",                        [{"alignmentgroup":"True","hovertemplate":"=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Yes","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"h","showlegend":true,"textposition":"auto","x":[2994],"xaxis":"x","y":["Yes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"No","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"h","showlegend":true,"textposition":"auto","x":[621],"xaxis":"x","y":["No"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type" ...

# %%
# @title Count *uuid* in Firebase that Captured in Kraken

plot_count(firebase_user_df.user_in_kraken, labels = 'Kraken')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c57b22eb-c8f4-460a-b863-6b42ccb33e6d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c57b22eb-c8f4-460a-b863-6b42ccb33e6d")) {                    Plotly.newPlot(                        "c57b22eb-c8f4-460a-b863-6b42ccb33e6d",                        [{"alignmentgroup":"True","hovertemplate":"=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"h","showlegend":true,"textposition":"auto","x":[8982],"xaxis":"x","y":["No"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Yes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"h","showlegend":true,"textposition":"auto","x":[2994],"xaxis":"x","y":["Yes"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type ...
